# %% [markdown]
# <a href="https://colab.research.google.com/github/ngwalker93/ADS-507-Final-Team-Project/blob/main/ADS507_Project_Workbook_Draft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import json

with open('/content/drug-ndc-0001-of-0001.json', 'r') as f:
    data = json.load(f)

df = pd.DataFrame(data['results'])
df.head()
# Out:
#   product_ndc                                       generic_name  \
# 0   80353-551  Rheumatoid arthritis and osteoarthritis recove...
# 1   80353-900  Gout recovery, Joint pain and inflammation rel...
# 2  80425-0021                                      Methocarbamol
# 3  80425-0022                                     Tizanidine HCL
# 4  80425-0033                                         Gabapentin
#
#                     labeler_name      brand_name  \
# 0                 HCBIOPHARM LLC       Archibone
# 1                     HCBIOPHARM        URICOZEN
# 2  Advanced Rx of Tennessee, LLC   Methocarbamol
# 3  Advanced Rx of Tennessee, LLC  Tizanidine HCL
# 4  Advanced Rx of Tennessee, LLC      Gabapentin
#
#                                   active_ingredients  finished  \
# 0  [{'name': 'ACHYRANTHES JAPONICA ROOT', 'streng...      True
# 1  [{'name': 'LONICERA JAPONICA FLOWER', 'strengt...      True
# 2  [{'name': 'METHOCARBAMOL', 'strength': '750 mg...      True
# 3  [{'name': 'TIZANIDINE HYDROCHLORIDE', 'strengt...      True
# 4   [{'name': 'GABAPENTIN', 'strength': '300 mg/1'}]      True
#
#                                            packaging listing_expiration_date  \
# 0  [{'package_ndc': '80353-551-01', 'description'...                20261231
# 1  [{'package_ndc': '80353-900-01', 'description'...                20261231
# 2  [{'package_ndc': '80425-0021-1', 'description'...                20261231
# 3  [{'package_ndc': '80425-0022-1', 'description'...                20261231
# 4  [{'package_ndc': '80425-0033-1', 'description'...                20261231
#
#                                              openfda      marketing_category  \
# 0  {'manufacturer_name': ['HCBIOPHARM LLC'], 'spl...  UNAPPROVED HOMEOPATHIC
# 1  {'manufacturer_name': ['HCBIOPHARM'], 'spl_set...  UNAPPROVED HOMEOPATHIC
# 2  {'manufacturer_name': ['Advanced Rx of Tenness...                    ANDA
# 3  {'manufacturer_name': ['Advanced Rx of Tenness...                    ANDA
# 4  {'manufacturer_name': ['Advanced Rx of Tenness...                    ANDA
#
#    ...             product_type   route marketing_start_date  \
# 0  ...           HUMAN OTC DRUG  [ORAL]             20211119
# 1  ...           HUMAN OTC DRUG  [ORAL]             20231207
# 2  ...  HUMAN PRESCRIPTION DRUG  [ORAL]             20190815
# 3  ...  HUMAN PRESCRIPTION DRUG  [ORAL]             20031211
# 4  ...  HUMAN PRESCRIPTION DRUG  [ORAL]             20110129
#
#                                         product_id brand_name_base  \
# 0   80353-551_2ac90fdd-c0ba-e65d-e063-6294a90a8dc6       Archibone
# 1   80353-900_2ac93f3e-7c81-cbbc-e063-6394a90abfc6        URICOZEN
# 2  80425-0021_2a9878c8-a143-224c-e063-6394a90a839d   Methocarbamol
# 3  80425-0022_2a987b85-efd6-eb95-e063-6394a90aef81  Tizanidine HCL
# 4  80425-0033_2e20f1f6-cc39-307e-e063-6394a90a6805      Gabapentin
#
#   application_number                                        pharm_class  \
# 0                NaN                                                NaN
# 1                NaN                                                NaN
# 2         ANDA040489  [Centrally-mediated Muscle Relaxation [PE], Mu...
# 3         ANDA076416  [Adrenergic alpha2-Agonists [MoA], Central alp...
# 4         ANDA090858  [Decreased Central Nervous System Disorganized...
#
#   dea_schedule brand_name_suffix marketing_end_date
# 0          NaN               NaN                NaN
# 1          NaN               NaN                NaN
# 2          NaN               NaN                NaN
# 3          NaN               NaN                NaN
# 4          NaN               NaN                NaN
#
# [5 rows x 22 columns]

# %%
with open('/content/drug-shortages-0001-of-0001.json', 'r') as f:
    data = json.load(f)

df_shortages = pd.DataFrame(data['results'])
df_shortages.head()
# Out:
#   update_type initial_posting_date   package_ndc  \
# 0  Reverified           02/22/2012  63323-486-27
# 1     Revised           02/15/2023  63323-426-10
# 2         New           11/03/2025  63481-627-70
# 3  Reverified           04/02/2020  23155-601-41
# 4  Reverified           10/12/2022  11534-195-01
#
#                                         generic_name  \
# 0                  Lidocaine Hydrochloride Injection
# 1                       Rocuronium Bromide Injection
# 2      Acetaminophen; Oxycodone Hydrochloride Tablet
# 3                  Midazolam Hydrochloride Injection
# 4  Amphetamine Aspartate Monohydrate, Amphetamine...
#
#                                     contact_info availability  \
# 0                                   888-386-1300    Available
# 1                                   888-386-1300    Available
# 2                                   800-828-9393          NaN
# 3                                   855-228-9470    Available
# 4  732-382-6085 Monday to Friday 9 am to 3:45 pm    Available
#
#                                      related_info  \
# 0                 Check wholesalers for inventory
# 1                 Check wholesalers for inventory
# 2  Discontinuation of the manufacture of the drug
# 3                                             NaN
# 4                                             NaN
#
#                                              openfda update_date  \
# 0  {'application_number': ['NDA006488'], 'brand_n...  01/06/2026
# 1  {'application_number': ['ANDA078651'], 'brand_...  01/06/2026
# 2                                                NaN  11/03/2025
# 3  {'application_number': ['ANDA090850'], 'brand_...  12/19/2025
# 4  {'application_number': ['ANDA209799'], 'brand_...  01/05/2026
#
#       therapeutic_category dosage_form  \
# 0  [Anesthesia, Pediatric]   Injection
# 1             [Anesthesia]   Injection
# 2    [Analgesia/Addiction]      Tablet
# 3  [Anesthesia, Neurology]   Injection
# 4             [Psychiatry]      Tablet
#
#                                         presentation  \
# 0  Xylocaine, Injection, 20 mg/1 mL (NDC 63323-48...
# 1  Rocuronium Bromide, Injection, 10 mg/1 mL (NDC...
# 2  Acetaminophen; Oxycodone Hydrochloride, Tablet...
# 3  Midazolam Hydrochloride, Injection, 5 mg/1 mL ...
# 4  Dextroamp Saccharate, Amp Aspartate, Dextroamp...
#
#                    company_name              status discontinued_date  \
# 0       Fresenius Kabi USA, LLC             Current               NaN
# 1       Fresenius Kabi USA, LLC             Current               NaN
# 2    Endo Pharmaceuticals, Inc.  To Be Discontinued        11/03/2025
# 3    Avet Pharmaceuticals, Inc.             Current               NaN
# 4  Sunrise Pharmaceutical, Inc.             Current               NaN
#
#   shortage_reason change_date resolved_note related_info_link
# 0             NaN         NaN           NaN               NaN
# 1             NaN         NaN           NaN               NaN
# 2             NaN         NaN           NaN               NaN
# 3             NaN         NaN           NaN               NaN
# 4             NaN         NaN           NaN               NaN

# %%
print("Columns in drug_products_ndc:")
print(df.columns.tolist())

print("\n" + "-"*50 + "\n")

print("Columns in drug_shortages:")
print(df_shortages.columns.tolist())
# Out:
# Columns in drug_products_ndc:
# ['product_ndc', 'generic_name', 'labeler_name', 'brand_name', 'active_ingredients', 'finished', 'packaging', 'listing_expiration_date', 'openfda', 'marketing_category', 'dosage_form', 'spl_id', 'product_type', 'route', 'marketing_start_date', 'product_id', 'brand_name_base', 'application_number', 'pharm_class', 'dea_schedule', 'brand_name_suffix', 'marketing_end_date']
#
# --------------------------------------------------
#
# Columns in drug_shortages:
# ['update_type', 'initial_posting_date', 'package_ndc', 'generic_name', 'contact_info', 'availability', 'related_info', 'openfda', 'update_date', 'therapeutic_category', 'dosage_form', 'presentation', 'company_name', 'status', 'discontinued_date', 'shortage_reason', 'change_date', 'resolved_note', 'related_info_link']
